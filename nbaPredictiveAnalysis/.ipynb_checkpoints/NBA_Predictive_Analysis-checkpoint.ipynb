# %% [markdown]
# # NBA Predictive Analysis

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from elopy import *
import pandas as pd
imp = Implementation()

# %%
# NBA season we will be analyzing
years = [2020]
months = ['october', 'november', 'december', 'january', 'february', 'march']

headers = []
rows = []
match_date = []
match_stats = []
raw_match_data = []
sortedRanking = []

imp.addPlayer('Hank')

for year in years:
    for month in months:
        # URL page we will scraping
        url = "https://www.basketball-reference.com/leagues/NBA_{}_games-{}.html".format(year, month)

        # this is the HTML from the given URL`
        html = urlopen(url)
        soup = BeautifulSoup(html, 'lxml')

        # use findALL() to get the column headers
        # Example -> soup.findAll('tr', limit=1), we use limit 1 to only get the first header

        # use getText() to extract the text we need into a list
        headers = [th.getText() for th in soup.findAll('tr', limit=1)[0].findAll('th')]
        unwanted_headers = ['\xa0', '\xa0','Notes']

        headers = [header for header in headers if header not in unwanted_headers]
        headers.insert(4, 'Result') #Adds Result Header
        headers.insert(5, 'Diff') #Adds Diff Header 
        # print(headers)

        # avoid the first header row -> [1:]
        rows = soup.findAll('tr')[1:]
        # print(rows)

        match_date = [[th.getText() for th in rows[i].findAll('th')]
                    for i in range(len(rows))]

        # print(game_date)

        match_stats = [[td.getText() for td in rows[i].findAll('td')]
                    for i in range(len(rows))]

        #     Deletes (by index) the unnecessary td concerning ['\xa0', '\xa0','Notes'] headers
        for i in range(len(rows)):
            del match_stats[i][5], match_stats[i][5],match_stats[i][6]

        # Adds Won or Lost value to Result Header
        for i in range(len(rows)):
            match_stats[i].insert(3, int(match_stats[i][2])- int(match_stats[i][4]))#Adds diff

            if int(match_stats[i][2]) > int(match_stats[i][5]):
                match_stats[i].insert(3,'Won')
            else: 
                match_stats[i].insert(3,'Lost')

        for i in range(len(rows)):
            imp.addPlayer(match_stats[i][1]) #Adds Team to Elo
            imp.addPlayer(match_stats[i][5]) #Adds Team to Elo

        # print (imp.getRatingList())   
        for i in range(len(rows)):
            if int(match_stats[i][2]) > int(match_stats[i][6]):
                imp.recordMatch(match_stats[i][1], match_stats[i][5],winner= match_stats[i][1])
            elif int(match_stats[i][2]) < int(match_stats[i][6]):
                imp.recordMatch(match_stats[i][1], match_stats[i][5],winner= match_stats[i][5])

        # print ("\n",imp.getRatingList())   

        sortedRanking = sortTuple((imp.getRatingList()))

        # Merge game _date and match stats into one list

        for i in range(len(match_date)):
            raw_match_data .append(match_date[i] + match_stats[i])

        # print(raw_match_data )

# %%
stats = pd.DataFrame(raw_match_data, columns = headers)
stats.head(1000)
# Out:
#                   Date Start (ET)         Visitor/Neutral  PTS Result  Diff  \
# 0    Tue, Oct 25, 2016      7:30p         New York Knicks   88   Lost   -29
# 1    Tue, Oct 25, 2016     10:00p               Utah Jazz  104   Lost    -9
# 2    Tue, Oct 25, 2016     10:30p       San Antonio Spurs  129    Won    29
# 3    Wed, Oct 26, 2016      7:00p        Dallas Mavericks  121   Lost    -9
# 28          New York Knicks  111  19,812
# 29        San Antonio Spurs   98  18,418
# ..                      ...  ...     ...
# 970        Sacramento Kings  122  17,608
# 971   Oklahoma City Thunder  112  18,203
# 972    Los Angeles Clippers  112  19,060
# 973         Detroit Pistons  112  19,607
# 974       Charlotte Hornets  122  18,196
# 975           Orlando Magic  104  18,846
# 976              Miami Heat  104  19,745
# 977         Milwaukee Bucks  102  18,717
# 978       San Antonio Spurs  107  18,418
# 979        Dallas Mavericks   98  20,324
# 980       Memphis Grizzlies   90  17,523
# 981  Portland Trail Blazers  124  19,482
# 982        Sacramento Kings   92  17,608
# 983          Boston Celtics  100  18,624
# 984           Brooklyn Nets  120  17,732
# 985          Indiana Pacers  102  17,923
# 986         Houston Rockets  117  18,055
# 987            Phoenix Suns  101  16,664
# 988      Los Angeles Lakers  116  18,997
# 989       Charlotte Hornets  109  16,489
# 990         Toronto Raptors  100  19,800
# 991       Memphis Grizzlies  113  16,770
# 992  Minnesota Timberwolves  119  15,747
# 993       San Antonio Spurs  107  18,418
# 994               Utah Jazz  114  19,911
# 995          Denver Nuggets  129  17,344
# 996        Sacramento Kings  120  17,608
# 997     Cleveland Cavaliers  128  20,562
# 998           Brooklyn Nets  104  13,911
# 999         New York Knicks   87  18,261
#
# [1000 rows x 9 columns]

# %%
ranking = pd.DataFrame(sortedRanking, columns = ['Team', 'Rank'])
ranking.head(len(rows))
# Out:
#                       Team          Rank
# 0          Toronto Raptors  1.301274e+03
# 1                     Hank  1.000000e+03
# 2           Boston Celtics  8.344067e+01
# 3     New Orleans Pelicans  3.396883e-01
# 4                Utah Jazz  6.821210e-13
# 5          New York Knicks  0.000000e+00
# 6      Cleveland Cavaliers  0.000000e+00
# 7   Portland Trail Blazers  0.000000e+00
# 8        San Antonio Spurs  0.000000e+00
# 9    Golden State Warriors  0.000000e+00
# 10        Dallas Mavericks  0.000000e+00
# 11          Indiana Pacers  0.000000e+00
# 12              Miami Heat  0.000000e+00
# 13           Orlando Magic  0.000000e+00
# 14         Detroit Pistons  0.000000e+00
# 15       Charlotte Hornets  0.000000e+00
# 16         Milwaukee Bucks  0.000000e+00
# 17          Denver Nuggets  0.000000e+00
# 18  Minnesota Timberwolves  0.000000e+00
# 19       Memphis Grizzlies  0.000000e+00
# 20      Philadelphia 76ers  0.000000e+00
# 21        Sacramento Kings  0.000000e+00
# 22            Phoenix Suns  0.000000e+00
# 23         Houston Rockets  0.000000e+00
# 24      Los Angeles Lakers  0.000000e+00
# 25      Washington Wizards  0.000000e+00
# 26           Atlanta Hawks  0.000000e+00
# 27           Chicago Bulls  0.000000e+00
# 28    Los Angeles Clippers  0.000000e+00
# 29   Oklahoma City Thunder -1.030003e-10
# 30           Brooklyn Nets -2.466618e-08

# %%
print(imp.predictMatch('Cleveland Cavaliers', 'Milwaukee Bucks'))
# Out:
# (0.5, 0.5)
